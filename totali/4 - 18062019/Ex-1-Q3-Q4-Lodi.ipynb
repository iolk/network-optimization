# %% [markdown]
# ## Totale N.
# ### Esercizio 3 punto 1
# Alessandro Lodi<br>
# Matricola 274425

# %% [markdown]
# ### Notebook Init

# %%
import networkx as nx
import gurobipy as gb
import matplotlib.pyplot as plt
from itertools import combinations, chain
import pygraphviz as pygv
import os
from IPython.display import SVG, display

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
class args:
    filename = "graph18062019.gml"
    scale = 40
    figsize = 10,10

# %%
def powerset(iterable):
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(len(s)+1))

# %% [markdown]
# ### Drawing functions

# %%
def DrawInitG(G, withedges=False):
    
    plt.figure(figsize=args.figsize)
    
    pos = {i:(G.nodes[i]['x'], G.nodes[i]['y']) for i in G.nodes()}
    
    nx.draw_networkx_nodes(G, 
                           pos=pos, 
                           node_shape='o', 
                           node_size=600,
                           node_color='red')
    
    nx.draw_networkx_labels(G, pos=pos, font_color='w', font_size=12)
    
    if withedges:
        nx.draw_networkx_edges(G,pos=pos, alpha=1.0)
        labels = {(i,j):G.get_edge_data(i,j,'cost').get('cost') for i,j in G.edges()}
        nx.draw_networkx_edge_labels(G, pos=pos, edge_labels=labels)
    
    plt.axis('off')
    plt.show()
    
def DrawSol(G, x):
    
    plt.figure(figsize=args.figsize)
    
    pos = {i:(G.nodes[i]['x'], G.nodes[i]['y']) for i in G.nodes()}

    
    nx.draw_networkx_nodes(G, 
                           pos=pos, 
                           node_shape='o', 
                           node_size=600,
                           node_color='red',
                           label=[G.nodes()])
    
    nx.draw_networkx_labels(G, pos=pos, font_color='w', font_size=12)
    
    for u,v in G.edges():
        if x[u,v].x > 0.01 and x[u,v].x < 0.9:
            nx.draw_networkx_edges(G, pos=pos,
                                   edgelist=[(u,v)],
                                   edge_color='r')
            
            nx.draw_networkx_edge_labels(G, pos=pos,
                                         edge_labels={(u,v):'{:.2f}'.format(x[u,v].x)})
        
        if x[u,v].x > 0.9:
            nx.draw_networkx_edges(G, pos=pos,
                                   edgelist=[(u,v)],
                                   edge_color='k')
        
    plt.axis('off')
    plt.show()

# %%
# Graph reading
basename = os.path.splitext(args.filename)[0]
G = nx.read_graphml (args.filename, node_type=int)
print ("G has", G.number_of_nodes(), "nodes and", G.number_of_edges(), "edges")
# Out:
# G has 30 nodes and 435 edges

# %%
DrawInitG(G, withedges=True)

# %% [markdown]
# ## Prize Collecting Steiner Tree (PCST) with limited number of hops
#
# ### Problem definition
#
# >**Given**
# >A symmetric graph $G=(V,E)$ and a cost $c_e > 0$ for each edge in $E$.
# >A root node $\{0\}$.
# >A revenue $p_j > 0$ for each node $j \in V \setminus \{0\}$.
# >
# >**Find**
# >A subtree 𝑇 rooted in {0} that maximizes the sum of the revenues of the nodes in 𝑇 minus the sum of the cost of the edges in 𝑇 such that the distance between {0} and any node in 𝑇 does not exceed H.
#
# ### Directed formulation
#
# Consider the bidirected graph $B=(V,A)$ that is obtained from $G$ by replacing each edge $e = \{i, j\}$ in $E$ with two directed arcs $(i, j)$ and
# $(j, i)$ (with corresponding weights $c_{ij} = c_{ji} = c_e )$ and a cost $c_e > 0$ for each edge in $E$
#
#
#
# > **PCST-H** is equivalent to find an optimal arborescence in B rooted in $\{0\}$
#
#
# #### Variables
# $$
# x_{ij} = \begin{cases}1 \text{ if arc $(i, j)$ is in the arborescence} \\
# 0 \text{ otherwise}
# \end{cases}
# $$
#
# $$
# y_j = \begin{cases} 1 \text{ if node j is in the arborescence}\\
# 0 \text{ otherwise}
# \end{cases}
# $$
#
# $$
# u_j = \{\text{number of arcs in the dipath (if any) induced by $x$ from \{0\} to $j$}\}
# $$
#
# #### MTZ formulation
#
# $$
# \begin{align}
# \min & \sum_{(i,j) \in A} c_{ij} x_{ij} - \sum_{j \in V \{0\}} p_j y_j \\
# \text{subject}& \text{ to} \\
# y_0 & = 1 \\
# \sum_{i \in \delta^-(j)} x_{ij} & = y_j \;\; \forall j \in V \setminus \{0\}\\
# (h+1)x_{ij} + u_i - u_j &\le h \;\; \forall (i,j) \in A \\
# y_i \le u_i &\le h y_i \;\; \forall i \in V\setminus \{0\}\\
# x_{jk} &\le y_j \;\; \forall k \in \delta^+(j), \;\; \forall j \in V \setminus\{0\}\\
# 0 \le u_j & \le n \;\; \forall j \in V \\
# x_{ij} & \in \{0,1\} \;\; \forall(i,j) \in A \\
# y_j & \in \{0,1\} \;\; \forall j \in V
# \end{align}
# $$

# %%
D = G.to_directed()
G.nodes(data=True)
# Out:
# NodeDataView({1: {'y': 45, 'customer': 2920, 'profit': 176, 'x': 22}, 2: {'y': 24, 'customer': 4167, 'profit': 712, 'x': 32}, 3: {'y': 9, 'customer': 2938, 'profit': 799, 'x': 32}, 4: {'y': 25, 'customer': 16100, 'profit': 438, 'x': 4}, 5: {'y': 30, 'customer': 1345, 'profit': 304, 'x': 37}, 6: {'y': 42, 'customer': 1910, 'profit': 305, 'x': 24}, 7: {'y': 20, 'customer': 4463, 'profit': 658, 'x': 11}, 8: {'y': 9, 'customer': 2302, 'profit': 546, 'x': 27}, 9: {'y': 3, 'customer': 1615, 'profit': 856, 'x': 20}, 10: {'y': 29, 'customer': 3379, 'profit': 871, 'x': 15}, 11: {'y': 39, 'customer': 3386, 'profit': 639, 'x': 16}, 12: {'y': 5, 'customer': 2385, 'profit': 758, 'x': 17}, 13: {'y': 45, 'customer': 2670, 'profit': 578, 'x': 19}, 14: {'y': 45, 'customer': 1253, 'profit': 266, 'x': 15}, 15: {'y': 36, 'customer': 4834, 'profit': 1000, 'x': 4}, 16: {'y': 32, 'customer': 4757, 'profit': 369, 'x': 8}, 17: {'y': 22, 'customer': 2763, 'profit': 708, 'x': 40}, 18: {'y': 26, 'customer': 4715, 'profit': 323, 'x': 14}, 19: {'y': 3, 'customer': 12456, 'profit': 410, 'x': 3}, 20: {'y': 13, 'customer': 1633, 'profit': 806, 'x': 14}, 21: {'y': 27, 'customer': 3538, 'profit': 575, 'x': 25}, 22: {'y': 24, 'customer': 2049, 'profit': 588, 'x': 27}, 23: {'y': 25, 'customer': 1585, 'profit': 439, 'x': 25}, 24: {'y': 42, 'customer': 4480, 'profit': 625, 'x': 5}, 25: {'y': 2, 'customer': 4011, 'profit': 636, 'x': 16}, 26: {'y': 34, 'customer': 4166, 'profit': 680, 'x': 23}, 27: {'y': 41, 'customer': 4686, 'profit': 379, 'x': 15}, 28: {'y': 13, 'customer': 3797, 'profit': 766, 'x': 30}, 29: {'y': 36, 'customer': 4361, 'profit': 347, 'x': 32}, 30: {'y': 5, 'customer': 1073, 'profit': 840, 'x': 23}})

# %%
root = 1
pcst = gb.Model()

# H represents the maximum number of hops
H = 4

# Objective function
pcst.ModelSense = gb.GRB.MAXIMIZE


# Decision Variables
x = pcst.addVars(D.edges(), vtype=gb.GRB.BINARY, 
                 obj = [- D[i][j]['cost'] for i,j in D.edges()], 
                 name = 'x')

y = pcst.addVars (G.nodes(), vtype = gb.GRB.BINARY, 
                  obj = [G.nodes[i]['profit'] for i in G.nodes()],
                 name = 'y')

u = pcst.addVars (G.nodes(), vtype = gb.GRB.CONTINUOUS, 
                  lb = 0.0, ub = G.number_of_nodes(),
                 name = 'u')


# Root is in the solution
pcst.addConstr(y[root] == 1, name = 'Fix_root')


# Each node has exactly one incoming arc
pcst.addConstrs((x.sum('*',j) == y[j] for j in G.nodes() if j != root), name='Node_in_deg')


# Precedence constraints (MTZ constraints)
pcst.addConstrs(((G.number_of_nodes() +  1) * x[i,j] + u[i] - u[j] <= G.number_of_nodes() for i,j in D.edges()),
                name = 'MTZ')


# Connectivity constraints
pcst.addConstrs((x[j,k] <= y[j] for j in G.nodes()
                 if j != root for k in D.neighbors(j)), name = 'Connect')

# Hop Constraints
pcst.addConstrs ((u[i] >= y[i] for i in G.nodes()
                  if i != root), name='VLB')

pcst.addConstrs ((u[i] <= H * y[i] for i in G.nodes()
                  if i != root), name='VUB')

pcst.update()
pcst.write('pcst.lp')
# Out:
# Academic license - for non-commercial use only - expires 2021-08-02
# Using license file /opt/gurobi/gurobi.lic

# %%
pcst.optimize()
# Out:
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1799 rows, 930 columns and 5279 nonzeros
# Model fingerprint: 0x43bf53dd
# Variable types: 30 continuous, 900 integer (900 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [2e+02, 5e+03]
#   Bounds range     [1e+00, 3e+01]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 176.0000000
# Presolve removed 59 rows and 31 columns
# Presolve time: 0.01s
# Presolved: 1740 rows, 899 columns, 5104 nonzeros
# Variable types: 29 continuous, 870 integer (870 binary)
#
# Root relaxation: objective 5.363267e+03, 79 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5363.26667    0   27  176.00000 5363.26667  2947%     -    0s
# H    0     0                     454.0000000 5288.86667  1065%     -    0s
#      0     0 4478.20000    0   29  454.00000 4478.20000   886%     -    0s
# H    0     0                     712.0000000 4478.20000   529%     -    0s
#      0     0 4291.00000    0   30  712.00000 4291.00000   503%     -    0s
#      0     0 4291.00000    0   32  712.00000 4291.00000   503%     -    0s
#      0     0 4119.20000    0   30  712.00000 4119.20000   479%     -    0s
#      0     0 4054.59323    0   29  712.00000 4054.59323   469%     -    0s
#      0     0 4051.38147    0   36  712.00000 4051.38147   469%     -    0s
#      0     0 4051.38147    0   36  712.00000 4051.38147   469%     -    0s
#      0     0 3785.06667    0   21  712.00000 3785.06667   432%     -    0s
#      0     0 3750.16667    0   25  712.00000 3750.16667   427%     -    0s
#      0     0 3750.16667    0   25  712.00000 3750.16667   427%     -    0s
#      0     0 3735.26667    0   25  712.00000 3735.26667   425%     -    0s
#      0     0 3734.52381    0   25  712.00000 3734.52381   425%     -    0s
#      0     0 3734.52381    0   25  712.00000 3734.52381   425%     -    0s
# H    0     0                     845.0000000 3734.52381   342%     -    0s
#      0     0 3580.93333    0   27  845.00000 3580.93333   324%     -    0s
#      0     0 3541.05952    0   31  845.00000 3541.05952   319%     -    0s
#      0     0 3540.95238    0   31  845.00000 3540.95238   319%     -    0s
#      0     0 3538.33333    0   30  845.00000 3538.33333   319%     -    0s
#      0     0 3538.33333    0   30  845.00000 3538.33333   319%     -    0s
#      0     0 3533.86396    0   38  845.00000 3533.86396   318%     -    0s
#      0     0 3532.96380    0   39  845.00000 3532.96380   318%     -    0s
#      0     0 3532.83599    0   38  845.00000 3532.83599   318%     -    0s
#      0     0 3526.77638    0   42  845.00000 3526.77638   317%     -    0s
#      0     0 3524.98474    0   42  845.00000 3524.98474   317%     -    0s
#      0     0 3524.65470    0   42  845.00000 3524.65470   317%     -    0s
#      0     0 3519.34062    0   46  845.00000 3519.34062   316%     -    0s
#      0     0 3518.86970    0   46  845.00000 3518.86970   316%     -    0s
#      0     0 3518.16916    0   45  845.00000 3518.16916   316%     -    0s
#      0     0 3518.16916    0   45  845.00000 3518.16916   316%     -    0s
#      0     0 3447.89421    0   27  845.00000 3447.89421   308%     -    0s
#      0     0 3447.89421    0   23  845.00000 3447.89421   308%     -    0s
#      0     0 3447.89421    0   26  845.00000 3447.89421   308%     -    0s
#      0     0 3447.89421    0   28  845.00000 3447.89421   308%     -    0s
#      0     0 3447.89421    0   46  845.00000 3447.89421   308%     -    0s
#      0     0 3447.89421    0   45  845.00000 3447.89421   308%     -    0s
#      0     0 3447.89421    0   42  845.00000 3447.89421   308%     -    0s
#      0     0 3447.89421    0   50  845.00000 3447.89421   308%     -    0s
#      0     0 3447.89421    0   50  845.00000 3447.89421   308%     -    0s
#      0     0 3447.89421    0   49  845.00000 3447.89421   308%     -    0s
#      0     0 3447.89421    0   48  845.00000 3447.89421   308%     -    0s
#      0     0 3447.89421    0   48  845.00000 3447.89421   308%     -    0s
#      0     0 3447.89421    0   45  845.00000 3447.89421   308%     -    0s
#      0     0 3447.89421    0   45  845.00000 3447.89421   308%     -    0s
#      0     0 3447.89421    0   45  845.00000 3447.89421   308%     -    0s
#      0     0 3447.89421    0   42  845.00000 3447.89421   308%     -    0s
#      0     2 3422.16667    0   42  845.00000 3422.16667   305%     -    0s
#  36499  9726 1263.32970   28   52  845.00000 1837.61694   117%  10.3    5s
#  36746  9890 1700.59510   50   90  845.00000 1700.59510   101%  10.3   10s
#
# Cutting planes:
#   Learned: 2
#   Gomory: 8
#   Cover: 3
#   Implied bound: 2
#   Projected implied bound: 11
#   Clique: 7
#   MIR: 34
#   Flow cover: 131
#   GUB cover: 3
#   Zero half: 22
#   Mod-K: 1
#   RLT: 3
#   Relax-and-lift: 10
#
# Explored 39050 nodes (422851 simplex iterations) in 12.95 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 845 712 454 176
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.450000000000e+02, best bound 8.450000000000e+02, gap 0.0000%

# %%
print("Solution: ", pcst.objVal)

DrawSol(D,x)
# Out:
# Solution:  845.0

# %% [markdown]
# ## Q4

# %%
for j in D.nodes():
    if j != root:
        x[root,j].Obj = -D[root][j]['cost']/2

pcst.addConstr(x.sum(root,'*') <= 8, name='Root_deg_out')

pcst.update()

# %%
pcst.reset()
pcst.optimize()
# Out:
# Discarded solution information
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1800 rows, 930 columns and 5308 nonzeros
# Model fingerprint: 0xb5467eb7
# Variable types: 30 continuous, 900 integer (900 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [2e+02, 5e+03]
#   Bounds range     [1e+00, 3e+01]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 176.0000000
# Presolve removed 59 rows and 31 columns
# Presolve time: 0.01s
# Presolved: 1741 rows, 899 columns, 5133 nonzeros
# Variable types: 29 continuous, 870 integer (870 binary)
#
# Root relaxation: objective 5.808600e+03, 79 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5808.60000    0   24  176.00000 5808.60000  3200%     -    0s
# H    0     0                     366.0000000 5808.60000  1487%     -    0s
# H    0     0                     891.0000000 5808.60000   552%     -    0s
#      0     0 5043.00000    0   28  891.00000 5043.00000   466%     -    0s
# H    0     0                    1425.5000000 5043.00000   254%     -    0s
#      0     0 4921.00000    0   30 1425.50000 4921.00000   245%     -    0s
#      0     0 4898.50000    0   32 1425.50000 4898.50000   244%     -    0s
# H    0     0                    2040.0000000 4898.50000   140%     -    0s
# H    0     0                    2186.0000000 4898.50000   124%     -    0s
#      0     0 4691.67742    0   35 2186.00000 4691.67742   115%     -    0s
# H    0     0                    2191.0000000 4691.67742   114%     -    0s
#      0     0 4667.10936    0   30 2191.00000 4667.10936   113%     -    0s
#      0     0 4664.12530    0   37 2191.00000 4664.12530   113%     -    0s
#      0     0 4664.05889    0   37 2191.00000 4664.05889   113%     -    0s
# H    0     0                    2320.0000000 4664.05889   101%     -    0s
#      0     0 4417.56667    0   25 2320.00000 4417.56667  90.4%     -    0s
#      0     0 4417.56667    0   24 2320.00000 4417.56667  90.4%     -    0s
#      0     0 4417.56667    0   24 2320.00000 4417.56667  90.4%     -    0s
#      0     0 4417.56667    0   24 2320.00000 4417.56667  90.4%     -    0s
#      0     0 4382.66667    0   29 2320.00000 4382.66667  88.9%     -    0s
#      0     0 4382.66667    0   29 2320.00000 4382.66667  88.9%     -    0s
#      0     0 4361.66667    0   17 2320.00000 4361.66667  88.0%     -    0s
#      0     0 4361.66667    0   17 2320.00000 4361.66667  88.0%     -    0s
#      0     0 4361.66667    0   13 2320.00000 4361.66667  88.0%     -    0s
#      0     0 4361.66667    0   17 2320.00000 4361.66667  88.0%     -    0s
#      0     0 4361.66667    0   17 2320.00000 4361.66667  88.0%     -    0s
# H    0     0                    2509.0000000 4361.66667  73.8%     -    0s
#      0     0 4361.66667    0   17 2509.00000 4361.66667  73.8%     -    0s
#      0     0 4361.66667    0   17 2509.00000 4361.66667  73.8%     -    0s
#      0     2 4154.53333    0   17 2509.00000 4154.53333  65.6%     -    0s
# *  181   130              20    2567.5000000 4154.53333  61.8%   5.0    0s
# H  727   395                    2619.5000000 3883.40000  48.2%   5.3    0s
# H  805   392                    2707.0000000 3854.75455  42.4%   5.3    0s
#
# Cutting planes:
#   Learned: 15
#   Gomory: 5
#   Cover: 12
#   Implied bound: 28
#   Clique: 3
#   MIR: 18
#   StrongCG: 1
#   Flow cover: 14
#   Inf proof: 12
#   Mod-K: 3
#   RLT: 10
#   Relax-and-lift: 26
#
# Explored 9203 nodes (64672 simplex iterations) in 1.06 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 2707 2619.5 2567.5 ... 891
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.707000000000e+03, best bound 2.707000000000e+03, gap 0.0000%

# %%
print("Solution: ", pcst.objVal)
DrawSol(D,x)
# Out:
# Solution:  2707.0
